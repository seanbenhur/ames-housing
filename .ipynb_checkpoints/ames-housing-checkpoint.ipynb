# %% [markdown]
# <h1>Housing Price Prediction with Stacking Regression Techniques</h1>

# %% [markdown]
# <h3>Importing Packages<h3>
#  Import the necessary packages that are useful for <b>Exploitation, Feature Engeneering, Visualization, Preprocessing, Ofcourse, Machine Learning</b>

# %%
#importing the basic packages
import numpy as np
import pandas as pd
#for statistics
from scipy import stats
from scipy.stats import norm, skew
#for plotting 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#for preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.pipeline import make_pipeline
#for machine learning
from sklearn.linear_model import ElasticNet, Lasso
from sklearn.kernel_ridge import KernelRidge
from sklearn.ensemble import RandomForestRegressor
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from catboost import CatBoostRegressor
import lightgbm
#for evaluation metrics
from sklearn.metrics import mean_squared_error
#for ignoring warnings
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
#reading the datasets
train = pd.read_csv('datasets/train.csv')
test = pd.read_csv('datasets/test.csv')

# %% [markdown]
# **Peek the Dataset**
#     It is always recommended to see the rows inside the both training and test sets using the pandas head()
#     function

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#check the numbers of samples and features
print("The train data size before dropping Id feature is :  ",train.shape)
print("The test data size before dropping Id feature is :  ",test.shape)

#Save the 'Id' column
train_ID = train['Id']
test_ID = test['Id']

#Now drop the  'Id' colum since it's unnecessary for  the prediction process.
train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)

#check again the data size after dropping the 'Id' variable
print("\nThe train data size after dropping Id feature is : ",train.shape) 
print("The test data size after dropping Id feature is : ",test.shape)
# Out:
# The train data size before dropping Id feature is :   (1460, 81)
# The test data size before dropping Id feature is :   (1459, 80)
#
# The train data size after dropping Id feature is :  (1460, 80)
# The test data size after dropping Id feature is :  (1459, 79)

# %%
train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# # Correlation<br>
# To find the columns that are more related to the target variable use **correaltion function**

# %%
corrmat = train.corr()
fig, ax = plt.subplots(figsize=(12,10))
sns.heatmap(corrmat, square=True)
plt.savefig('heatmap.png')

# %%
#scatter plots
sns.set()
columns = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(train[columns],height=2.5)
plt.show()
plt.savefig('scatter.png')

# %% [markdown]
# # OutLiers <br>
# According to the documentation of this Datasets, this dataset contains some outliers, it affects our scores badly,so using scatter plots let's look for outliers

# %%
variable =  'GrLivArea'
data = pd.concat([train['SalePrice'],train[variable]],axis=1)
data.plot.scatter(x=variable, y='SalePrice')

# %% [markdown]
# There seems to be 2 extreme outliers on the bottom right, really large houses that sold for really cheap. More generally, the author of the dataset recommends removing 'any houses with more than 4000 square feet' from the dataset.

# %%
variable =  'TotalBsmtSF'
data = pd.concat([train['SalePrice'],train[variable]],axis=1)
data.plot.scatter(x=variable, y='SalePrice')

# %% [markdown]
# We can handle our Outliers by applying log transform to our target

# %% [markdown]
# # Preprocess the Target Variable<br>
# Preprocess the target variable in such a way, that we can handle the outliers

# %%
sns.distplot(train['SalePrice'], fit = norm)

# %%
#We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
train["SalePrice"] = np.log1p(train["SalePrice"])
sns.distplot(train['SalePrice'] , fit=norm);
plt.savefig('logdist.png')

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
y_train =  train.SalePrice.values
combined_data = pd.concat((train, test)).reset_index(drop=True)
combined_data.drop(['SalePrice'], axis=1, inplace=True)
print("Shape of the combined data: {}".format(combined_data.shape))
# Out:
# Shape of the combined data: (2919, 79)

# %% [markdown]
# # Missing Values<br>
#    As using missing values will make the model poor, we will impute the missing values but before moving on, let's do some  EDA on our missing values

# %%
missing = combined_data.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar(figsize=(16,10))
plt.savefig('missing.png')

# %%
#check out the percentile of missing values in each variables
total = combined_data.isnull().sum().sort_values(ascending=False)
percent = (combined_data.isnull().sum()/combined_data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total,percent],axis=1,keys=['Total','Percent'])
missing_data.head(25)
# Out:
#               Total   Percent
# PoolQC         2909  0.996574
# MiscFeature    2814  0.964029
# Alley          2721  0.932169
# Fence          2348  0.804385
# FireplaceQu    1420  0.486468
# LotFrontage     486  0.166495
# GarageCond      159  0.054471
# GarageQual      159  0.054471
# GarageYrBlt     159  0.054471
# GarageFinish    159  0.054471
# GarageType      157  0.053786
# BsmtCond         82  0.028092
# BsmtExposure     82  0.028092
# BsmtQual         81  0.027749
# BsmtFinType2     80  0.027407
# BsmtFinType1     79  0.027064
# MasVnrType       24  0.008222
# MasVnrArea       23  0.007879
# MSZoning          4  0.001370
# BsmtHalfBath      2  0.000685
# Utilities         2  0.000685
# Functional        2  0.000685
# BsmtFullBath      2  0.000685
# BsmtFinSF2        1  0.000343
# BsmtFinSF1        1  0.000343

# %% [markdown]
# # Impuation of missing values<br>
# Lets fill the missing values using  simple pandas fillna() method<br> **Note:** You can use some other methods also, such as *scikit learn's Imputer()*

# %%
for col in ('PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
            'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
            'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
            'MasVnrType'): 
    combined_data[col] = combined_data[col].fillna('None')
    
#Group by neighborhood and fill in missing value by the median LotFrontage of all the neighborhood
combined_data["LotFrontage"] = combined_data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))

combined_data['MSZoning'] = combined_data['MSZoning'].fillna(combined_data['MSZoning'].mode()[0])

combined_data['MasVnrArea'] = combined_data['MasVnrArea'].fillna(0)

#Utilities : For this categorical feature all records are "AllPub", except for one "NoSeWa" and 2 NA . Since the house with 'NoSewa' is in the training set, 
#this feature won't help in predictive modelling. We can then safely remove it.
combined_data = combined_data.drop(['Utilities'], axis=1)

combined_data["Functional"] = combined_data["Functional"].fillna("Typ")

combined_data['Electrical'] = combined_data['Electrical'].fillna(combined_data['Electrical'].mode()[0])

combined_data['KitchenQual'] = combined_data['KitchenQual'].fillna(combined_data['KitchenQual'].mode()[0])

combined_data['Exterior1st'] = combined_data['Exterior1st'].fillna(combined_data['Exterior1st'].mode()[0])
combined_data['Exterior2nd'] = combined_data['Exterior2nd'].fillna(combined_data['Exterior2nd'].mode()[0])

combined_data['SaleType'] = combined_data['SaleType'].fillna(combined_data['SaleType'].mode()[0])

for col in ('GarageYrBlt', 'GarageArea', 'GarageCars',
            'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    combined_data[col] = combined_data[col].fillna(0)

# %%
#Check remaining missing values if any 
combined_data_na = (combined_data.isnull().sum() / len(combined_data)) * 100
combined_data_na = combined_data_na.drop(combined_data_na[combined_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :combined_data_na})
missing_data
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %% [markdown]
# # Feature Engeneering<br>
# Feature Engeneering is an important task in machine learning, as this dataset conatins 80 columns we can tweak some of the attributes to create a robust model

# %%
#MSSubClass=The building class
combined_data['MSSubClass'] = combined_data['MSSubClass'].apply(str)


#Changing OverallCond into a categorical variable
combined_data['OverallCond'] = combined_data['OverallCond'].astype(str)


#Year and month sold are transformed into categorical features.
combined_data['YrSold'] = combined_data['YrSold'].astype(str)
combined_data['MoSold'] = combined_data['MoSold'].astype(str)

# %% [markdown]
# <h3>Label Encoder:</h3><br>
# Using LabelEncoder change the categorical attributes to numerical attributes

# %%
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')
# process columns, apply LabelEncoder to categorical features
for c in cols:
    lbl = LabelEncoder() 
    lbl.fit(list(combined_data[c].values)) 
    combined_data[c] = lbl.transform(list(combined_data[c].values))

# shape        
print('Shape all_data: {}'.format(combined_data.shape))
# Out:
# Shape all_data: (2919, 78)

# %%
# Adding total sqfootage feature 
combined_data['TotalSF'] = combined_data['TotalBsmtSF'] + combined_data['1stFlrSF'] + combined_data['2ndFlrSF']

# %% [markdown]
# # Skewness<br>
# The next problem is *skewness* skewness may be an obstacle for our model, but before handling it, lets plot some visualizations to explore which columns contain more skewness

# %%
numerical_features = combined_data.dtypes[combined_data.dtypes != 'object'].index
#skewness
skewed_features = combined_data[numerical_features].apply(lambda x: skew(x.dropna())).sort_values(ascending= False)
print('Skewness in  numerical features:\n')
skewness =  pd.DataFrame({'Skew': skewed_features})
skewness.plot.bar(figsize=(16,10))
plt.savefig('skew.png')
# Out:
# Skewness in  numerical features:

# %% [markdown]
# <h3>Handling the Skewness</h3>
# Now, we can handle the skewness using boxcox transformation, which is better for skewness

# %%
skewness = skewness[abs(skewness) > 0.75]
print("There are {} skewed numerical features to Box Cox transform".format(skewness.shape[0]))

from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    combined_data[feat] = boxcox1p(combined_data[feat], lam)
# Out:
# There are 59 skewed numerical features to Box Cox transform

# %%
combined_data = pd.get_dummies(combined_data)
print('Shape of Combined Data: ',combined_data.shape)
train = combined_data[:ntrain]
test = combined_data[ntrain:]
print('Shape of training data: ',train.shape)
print('Shape of testing data: ',test.shape)
# Out:
# Shape of Combined Data:  (2919, 221)
# Shape of training data:  (1460, 221)
# Shape of testing data:  (1459, 221)

# %% [markdown]
# <h2>Validation functions</h2>
# Validation functions are necessary for evaluation of  our models

# %%
#Validation function
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %%
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %% [markdown]
# # Model Creation
# Let's define some pipeines for various regression methods

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)
rf =  RandomForestRegressor(n_estimators= 1000, random_state=42)

# %%
model_lgb = lightgbm.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2320,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %%
lasso_score = rmsle_cv(lasso)
print("Lasso score: ",(lasso_score.mean()), (lasso_score.std()))
# Out:
# Lasso score:  0.12400528274844447 0.016462948297415198

# %%
Enet_score = rmsle_cv(ENet)
print("Elastic Net score: ",(Enet_score.mean()), (Enet_score.std()))
# Out:
# Elastic Net score:  0.12404584197270133 0.016526375965680188

# %%
KRR_score = rmsle_cv(KRR)
print("Kernel Ridge score: ",(KRR_score.mean()), (KRR_score.std()))
# Out:
# Kernel Ridge score:  0.12620375021483035 0.012721254844825381

# %%
rf_score = rmsle_cv(rf)
print("Random Forest score: ",(rf_score.mean()), (rf_score.std()))
# Out:
# Random Forest score:  0.1425196240257057 0.007982187621097585

# %%
lgb_score = rmsle_cv(model_lgb)
print("LightGBM score: ",(lgb_score.mean()), (lgb_score.std()))
# Out:
# LightGBM score:  0.12455143845718401 0.009387383986409453

# %%
class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models
        
    # we define clones of the original models to fit the data in
    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        # Train cloned base models
        for model in self.models_:
            model.fit(X, y)

        return self
    
    #Now we do the predictions for cloned models and average them
    def predict(self, X):
        predictions = np.column_stack([
            model.predict(X) for model in self.models_
        ])
        return np.mean(predictions, axis=1)

# %%
averaged_models = AveragingModels(models = (ENet, KRR, lasso, rf))

average_models_score = rmsle_cv(averaged_models)
print("Averaged models score: ",(average_models_score.mean()), (average_models_score.std()))
# Out:
# Averaged models score:  0.1203340221380655 0.013754282222486128

# %% [markdown]
# # Stacking the Average Models

# %%
class StackingAveragedModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, base_models, meta_model, n_folds=5):
        self.base_models = base_models
        self.meta_model = meta_model
        self.n_folds = n_folds
   
    # We again fit the data on clones of the original models
    def fit(self, X, y):
        self.base_models_ = [list() for x in self.base_models]
        self.meta_model_ = clone(self.meta_model)
        kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=156)
        
        # Train cloned base models then create out-of-fold predictions
        # that are needed to train the cloned meta-model
        out_of_fold_predictions = np.zeros((X.shape[0], len(self.base_models)))
        for i, model in enumerate(self.base_models):
            for train_index, holdout_index in kfold.split(X, y):
                instance = clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index], y[train_index])
                y_pred = instance.predict(X[holdout_index])
                out_of_fold_predictions[holdout_index, i] = y_pred
                
        # Now train the cloned  meta-model using the out-of-fold predictions as new feature
        self.meta_model_.fit(out_of_fold_predictions, y)
        return self
   
    #Do the predictions of all base models on the test data and use the averaged predictions as 
    #meta-features for the final prediction which is done by the meta-model
    def predict(self, X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_ ])
        return self.meta_model_.predict(meta_features)

# %%
stacked_averaged_models = StackingAveragedModels(base_models = (ENet, KRR, rf),
                                                 meta_model = lasso)

sam_score = rmsle_cv(stacked_averaged_models)
print("Stacking Averaged models score: ",(sam_score.mean()), (sam_score.std()))
# Out:
# Stacking Averaged models score:  0.12115617877609608 0.01419218137218539

# %%
model_lgb.fit(train, y_train)
lgb_train_pred = model_lgb.predict(train)
lgb_pred = np.expm1(model_lgb.predict(test.values))
print(rmsle(y_train, lgb_train_pred))
# Out:
# 0.07504210288827648

# %%
stacked_averaged_models.fit(train.values, y_train)
stacked_train_pred = stacked_averaged_models.predict(train.values)
stacked_pred = np.expm1(stacked_averaged_models.predict(test.values))
print(rmsle(y_train, stacked_train_pred))
# Out:
# 0.09026134027934644

# %%
'''RMSE on the entire Train data when averaging'''

print('RMSLE score on train data:')
print(rmsle(y_train,stacked_train_pred*0.70 +
                lgb_train_pred*0.30 ))
# Out:
# RMSLE score on train data:
# 0.08336010128042441

# %%
ensemble = stacked_pred*0.70 +  lgb_pred*0.30

# %%
sub = pd.DataFrame()
sub['Id'] = test_ID
sub['SalePrice'] = stacked_pred
sub.to_csv('ensemble0.csv',index=False)

# %%
from IPython.display import FileLink
FileLink(r'ensemble0.csv')
# Out:
# /kaggle/working/ensemble0.csv
